# %%
# importing necessary libraries
import matplotlib.pyplot as plt

# %%
#2 data sets
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

visits_per_month = [9695, 7909, 10831, 12942, 12495, 16794, 14161, 12762, 12777, 12439, 10309, 8724]

# numbers of limes of different species sold each month
key_limes_per_month = [92.0, 109.0, 124.0, 70.0, 101.0, 79.0, 106.0, 101.0, 103.0, 90.0, 102.0, 106.0]
persian_limes_per_month = [67.0, 51.0, 57.0, 54.0, 83.0, 90.0, 52.0, 63.0, 51.0, 44.0, 64.0, 78.0]
blood_limes_per_month = [75.0, 75.0, 76.0, 71.0, 74.0, 77.0, 69.0, 80.0, 63.0, 69.0, 73.0, 82.0]

# %%
#3 create a figure of width 12 and height 8
plt.figure(figsize=(12, 8), frameon=True)

#4 make two charts in one figure, laid out side-by-side.
# create the left subplot
ax1 = plt.subplot(1, 2, 1)

#6 plot the total page visits over the past year as a line.
# create the list of x-values
x_values = range(len(months))

#7 plot the total page visits
plt.plot(x_values, visits_per_month, marker='*')
#14 add titile
plt.title('Page visits over time')
#9 label axises
plt.xlabel('Months')
plt.ylabel('Visits')
#10 set x-axis ticks
ax1.set_xticks(x_values)
#11 label the x-axis tick labels
ax1.set_xticklabels(months)


#5 create the right subplot
ax2 = plt.subplot(1, 2, 2)
# Plotting multiple lime species
#12 plot three lines at right subplot
plt.plot(x_values, key_limes_per_month, color="#2007C2")
plt.plot(x_values, persian_limes_per_month, color="#C2B509")
plt.plot(x_values, blood_limes_per_month, color='#E2552D')
#14 add titile
plt.title('Sales of limes')
#12 add legend
plt.legend(['key', 'persian', 'blood'])
plt.xlabel('Months')
plt.ylabel('Numbers of limes')
# #13 set x-axis ticks and label the x-axis tick labels
ax2.set_xticks(x_values)
ax2.set_xticklabels(months)

#14 adjust the margins
plt.subplots_adjust(bottom=0.2, wspace=0.25)
#15 save figure
plt.savefig('visits_sales_months.png')
